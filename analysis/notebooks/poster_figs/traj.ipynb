# %%
# %cd /home/govind/gov_semproject/GridCellsCopy
# Out:
# /home/govind/gov_semproject/GridCellsCopy

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import analysis_utils as a_utils
import sim_utils as s_utils
import g_utils

# %%
stell_spks , intrnrn_spks = s_utils.load_spikes(sim_id='5e3_2')

pos,vel,t_s = g_utils.posn_vel_input(sim_dur=45000,sim_id='5e3_2',sim_num=0,n_trials=5)
# Out:
# Hallelujah
# Stellate File Path :  data/5e3_2/stell_spks_5e3_2.hdf5
# Interneuron File Path :  data/5e3_2/intrnrn_spks_5e3_2.hdf5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_386755/3917977887.py in <module>
#       1 stell_spks , intrnrn_spks = s_utils.load_spikes(sim_id='5e3_2')
#       2
# ----> 3 pos,vel,t_s = g_utils.posn_vel_input(sim_dur=45000,sim_id='5e3_2',sim_num=0,n_trials=5)
#
# ~/gov_semproject/GridCellsCopy/g_utils.py in posn_vel_input(sim_id, sim_num, n_trials, sim_dur)
#      50     """
#      51     params = s_utils.load_sim_params(sim_id=sim_id)["0"]
# ---> 52     traj = Trajectory1D(params, save_mem=False)
#      53     t_ms = np.arange(traj.init_allothetic_dur,params["sim_dur"])
#      54     t_ms_idx = (t_ms/0.025).astype('int')
#
# ~/gov_semproject/GridCellsCopy/network_configs/instrumentations/trajectory1D.py in __init__(self, params, save_mem)
#      28             self.const_vel()
#      29         elif self.params["vel_type"] == "input":
# ---> 30             self.input_velocity()
#      31         elif self.params["vel_type"] == "ACVT-1DAC":
#      32             self.figure_1_pulse_input()
#
# ~/gov_semproject/GridCellsCopy/network_configs/instrumentations/trajectory1D.py in input_velocity(self)
#     116
#     117
# --> 118         else:
#     119              self.intrnrn_theta = np.full_like(self.t, 0)
#     120
#
# ~/gov_semproject/GridCellsCopy/network_configs/instrumentations/trajectory1D.py in amp_mod_function(dis)
#      96                  term_min = (amp_base - amp_min) * (np.exp(-((dis / resp) ** 2)))
#      97                  return amp_base - term_min
# ---> 98
#      99             # if self.params['tuning'] == 3:
#     100                  #term_max = (amp_max - amp_base) * (np.exp(-((dis / resp) ** 2)))
#
# UnboundLocalError: local variable 'amp_max' referenced before assignment
