# %%
# %cd /home/govind/gov_semproject/GridCellsCopy
# Out:
# /home/govind/gov_semproject/GridCellsCopy

# %%
import analysis_utils as a_utils
import sim_utils as s_utils
import g_utils
import matplotlib.pyplot as plt
import numpy as np

# %%
amp_list = [0,1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3]
sim_id_list = ['control1','1e3','2e3','3e3','4e3','5e3','6e3','7e3']
err_list = []

for id in sim_id_list:
    err_list.append(g_utils.total_error(id,num_trials=5))

plt.scatter(amp_list,err_list)
plt.show()
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# ...

# %%
plt.plot(amp_list,err_list)
plt.show()

# %%
amp_list = [0,1e-3,2e-3,3e-3,4e-3,5e-3]
sim_id_list = ['control2','1e3_1','2e3_1','3e3_1','4e3_1','5e3_1']
err_list = []

for id in sim_id_list:
    err_list.append(g_utils.total_error(id,num_trials=5))

plt.scatter(amp_list,err_list)
plt.show()
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control2/stell_spks_control2.hdf5
# Interneuron File Path :  data/control2/intrnrn_spks_control2.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control2/stell_spks_control2.hdf5
# Interneuron File Path :  data/control2/intrnrn_spks_control2.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control2/stell_spks_control2.hdf5
# Interneuron File Path :  data/control2/intrnrn_spks_control2.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/control2/stell_spks_control2.hdf5
# ...

# %%
plt.plot(amp_list,err_list)
plt.show()

# %%
amp_list = [0,2e-3,3e-3,4e-3,5e-3,6e-3]
sim_id_list = ['control3','2e3_2','3e3_2','4e3_2','5e3_2','6e3_2']
err_list = []

for id in sim_id_list:
    err_list.append(g_utils.total_error(id,num_trials=5))

plt.scatter(amp_list,err_list)
plt.show()
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control3/stell_spks_control3.hdf5
# Interneuron File Path :  data/control3/intrnrn_spks_control3.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control3/stell_spks_control3.hdf5
# Interneuron File Path :  data/control3/intrnrn_spks_control3.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control3/stell_spks_control3.hdf5
# Interneuron File Path :  data/control3/intrnrn_spks_control3.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/control3/stell_spks_control3.hdf5
# ...

# %%
ra_sim_list = ['control1','1e3','2e3','3e3','4e3','5e3','6e3','7e3']
ra_1_sim_list = ['control2','1e3_1','2e3_1','3e3_1','4e3_1','5e3_1','6e3_1','7e3_1']
ra_2_sim_list = ['control3','1e3_2','2e3_2','3e3_2','4e3_2','5e3_2','6e3_2','7e3_2']

ra_err,ra1_err,ra2_err = [], [], []

amp_list = [i for i in range(8)]

for id1,id2,id3 in zip(ra_sim_list,ra_1_sim_list,ra_2_sim_list):
    ra_err.append(g_utils.total_error(sim_id=id1,num_trials=5))
    ra1_err.append(g_utils.total_error(sim_id=id2,num_trials=5))
    ra2_err.append(g_utils.total_error(sim_id=id3,num_trials=5))
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# ...

# %%
amp_list.extend([3.2,3.4,3.6,3.8,4.2,4.4,4.6,4.8])

ext_ra2_list = ['32e3_2','34e3_2','36e3_2','38e3_2','42e3_2','44e3_2','46e3_2','48e3_2']

for id in ext_ra2_list:
    ra2_err.append(g_utils.total_error(sim_id=id,num_trials=5,sim_num=0))
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/32e3_2/stell_spks_32e3_2.hdf5
# Interneuron File Path :  data/32e3_2/intrnrn_spks_32e3_2.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/32e3_2/stell_spks_32e3_2.hdf5
# Interneuron File Path :  data/32e3_2/intrnrn_spks_32e3_2.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/32e3_2/stell_spks_32e3_2.hdf5
# Interneuron File Path :  data/32e3_2/intrnrn_spks_32e3_2.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/32e3_2/stell_spks_32e3_2.hdf5
# ...

# %%
ra_3_sim_list = ['1e3_3','2e3_3','3e3_3','4e3_3','5e3_3','6e3_3','7e3_3']

ra3_err = []

amp_list_3 = [i for i in range(1,8,1)]

for id in ra_3_sim_list:
    ra3_err.append(g_utils.total_error(sim_id=id,num_trials=5))
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/1e3_3/stell_spks_1e3_3.hdf5
# Interneuron File Path :  data/1e3_3/intrnrn_spks_1e3_3.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/1e3_3/stell_spks_1e3_3.hdf5
# Interneuron File Path :  data/1e3_3/intrnrn_spks_1e3_3.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/1e3_3/stell_spks_1e3_3.hdf5
# Interneuron File Path :  data/1e3_3/intrnrn_spks_1e3_3.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/1e3_3/stell_spks_1e3_3.hdf5
# ...

# %%
plt.scatter(amp_list_3[1:],ra3_err)
plt.show()

# %%
print(len(amp_list))
print(len(ra2_err))
# Out:
# 28
# 25

# %%
plt.figure(figsize=(12,6))

#plt.plot(amp_list,ra_err,label='Offset = 1x$10^{-2}$ nA',marker='x')
#plt.plot(amp_list,ra1_err,label='Offset = 0.5x$10^{-2}$ nA',marker='o')
plt.scatter(amp_list,ra2_err,label='Offset = 0.75x$10^{-2}$ nA',marker='s')
plt.xlabel("Injected theta current amplitude (in $10^{-3}$ nA)")
plt.ylabel("Cumulative decoding error")
plt.legend()
plt.show()

# %%
g_utils.plot_mult_error(sim_id_list=['1e3'],sim_num=0,num_trials=5)
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/1e3/stell_spks_1e3.hdf5
# Interneuron File Path :  data/1e3/intrnrn_spks_1e3.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/1e3/stell_spks_1e3.hdf5
# Interneuron File Path :  data/1e3/intrnrn_spks_1e3.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/1e3/stell_spks_1e3.hdf5
# Interneuron File Path :  data/1e3/intrnrn_spks_1e3.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/1e3/stell_spks_1e3.hdf5
# Interneuron File Path :  data/1e3/intrnrn_spks_1e3.hdf5
# ...

# %%
test = g_utils.decode_func(sim_id='control1',sim_dur=45000,sim_num=0,n_trials=5)
print(np.shape(test))
# Out:
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  3
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  4
# Hallelujah
# ...

# %%
g_utils.plot_mult_stddev(sim_id_list=['control1','2e3','4e3','5e3','6e3','7e3'],num_trials=5)
# Out:
# num_trials :  5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  1
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  2
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# Trial Number  3
# Hallelujah
# ...

# %%
g_utils.plot_mult_error(sim_id_list=['control1','2e3','4e3','5e3','6e3','7e3'],num_trials=5)
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Number of trials: 5
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 5.25549528e-01
#  5.25788635e-01 5.26029618e-01]
# Top-level groups: ['0', '1', '2', '3', '4']
# 0 contains: ['stell_spks']
# 1 contains: ['stell_spks']
# 2 contains: ['stell_spks']
# 3 contains: ['stell_spks']
# 4 contains: ['stell_spks']
# Trial Number  0
# Hallelujah
# Stellate File Path :  data/control1/stell_spks_control1.hdf5
# Interneuron File Path :  data/control1/intrnrn_spks_control1.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_230556/539934837.py in <module>
# ----> 1 g_utils.plot_mult_error(sim_id_list=['control1','2e3','4e3','5e3','6e3','7e3'],num_trials=5)
#
# ~/gov_semproject/GridCellsCopy/g_utils.py in plot_mult_error(sim_id_list, sim_num, save, num_trials)
# ...

# %%
v_2e3 = s_utils.load_data(sim_id='res1',sim_num=0,data_id='intrnrn_theta_dc')
v_2e3_stell, v_2e3_intr = s_utils.load_spikes(sim_id='res1',sim_num=0)


fig,ax=plt.subplots(2,1,figsize=(18,10))
ax[0].plot(np.linspace(0,len(v_2e3),len(v_2e3)),v_2e3)
ax[1].eventplot(v_2e3_intr[10])
ax[0].set_xlim(10000,13000)
ax[1].set_xlim(10000,13000)
plt.show()
# Out:
# Hallelujah
# Stellate File Path :  data/res1/stell_spks_res1.hdf5
# Interneuron File Path :  data/res1/intrnrn_spks_res1.hdf5
