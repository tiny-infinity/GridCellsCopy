# %%
# %cd /home/govind/gov_semproject/GridCellsCopy
# Out:
# /home/govind/gov_semproject/GridCellsCopy

# %%
from g_utils import plot_mult_stddev
import matplotlib.pyplot as plt
#import numpy as np
import h5py
from param import Param
import sim_utils as s_utils
import analysis_utils as a_utils
import matplotlib.cm as cm

# %% [markdown]
# #### Parameter Sets we have
# - ```THETA_CONST``` : Constant DC Input
# - ```THETA_OSC``` : Amplitude-Modulated Oscillatory DC Input
# - ```THETA_MOD``` : Constant-Amplitude Oscillatory DC Input
# - ```NEW_THETA``` : Stochastic Resonance Parameters + Constant DC-Input
# - ```NEW_THETA_1``` : Stochastic Resonance Parameters + More neurons + Constant DC-Input
# - ```NEW_THETA``` : Stochastic Resonance Parameters + More neurons + const.Amplitude Oscillation DC-Input
# - ```NEW_THETA_1``` : Stochastic Resonance Parameters + More neurons + Amplitude-Modulated Oscillatory DC Input <br>
# <br>
# Amplitude of DC Oscillations = 1.00
# - ```THTA_1``` :
# - ```THTA_11```
# - ```THTA_12``` <br>
# <br>
# Amplitude of DC Oscillations = 3.00
# - ```THTA_2```
# - ```THTA_21```
# - ```THTA_22``` <br>
# <br>
# Same parameters as paper. Used to test effect of removing intrinsic theta
# - ```THTA_3``` - Control
# - ```THTA_4``` - Intrinsic Theta removed

# %%
THTA_1_list = ["THTA_1","THTA_11","THTA_12"]
THTA_2_list = ["THTA_2","THTA_21","THTA_22"]
compare_params_list = ["THTA_CONST","NEW_THETA_1"]

# %%
plot_mult_stddev(THTA_1_list)
# Out:
# [2.49986607e-11 4.99964287e-11 7.49933038e-11 ... 1.99285575e+00
#  1.99305575e+00 1.99325575e+00]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_98812/3824948524.py in <module>
# ----> 1 plot_mult_stddev(THTA_1_list)
#
# ~/gov_semproject/GridCellsCopy/g_utils.py in plot_mult_stddev(sim_id_list, sim_num, save, num_trials)
#      69     """
#      70
# ---> 71     _,_,t_s=posn_vel_input(sim_id_list[0],sim_num)
#      72     plt.figure(figsize=(22,10))
#      73     for sim_id in sim_id_list:
#
# ~/gov_semproject/GridCellsCopy/g_utils.py in posn_vel_input(sim_id, sim_num, n_trials, sim_dur)
#      51     params = s_utils.load_sim_params(sim_id=sim_id)["0"]
#      52     traj = Trajectory1D(params, save_mem=False)
# ---> 53     t_ms = np.arange(traj.init_allothetic_dur,params["sim_dur"])
#      54     t_ms_idx = (t_ms/0.025).astype('int')
# ...

# %%
g_utils.plot_mult_stddev(THTA_2_list)

# %%
g_utils.plot_mult_stddev(compare_params_list)
